# %%
import pandas as pd
import requests
import os

# %% [markdown]
# ### Download files from the GitHub repository for analysis

# %%
#Base URL of repository used for download
url_dwl = 'https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/'
folder_name = 'dados_emprestimos'

# %%
#Creating directory to save CSV files
if not os.path.exists('Dados/Emprestimos/'):
    os.makedirs('Dados/Emprestimos/')
    print('Directory created successfully')
else:
    print('existing directory')
# Out:
# existing directory

# %%
#loop to download each file found in the repository
for i in range(20101, 20202):
    file_name = f'emprestimos-{i}.csv'
    file_path = f'Dados/Emprestimos/{file_name}'
    url = f'{url_dwl}/{folder_name}/{file_name}'
    
    if os.path.exists(file_path):
        print(f'{file_name} already downloaded.')
    else:
        response = requests.get(url)
        
        if response.status_code == 200:
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f'{file_name} successfully downloaded!')
        else:
            print(f'{file_name} not found in repository')
# Out:
# emprestimos-20101.csv already downloaded.
# emprestimos-20102.csv already downloaded.
# emprestimos-20103.csv not found in repository
# emprestimos-20104.csv not found in repository
# emprestimos-20105.csv not found in repository
# emprestimos-20106.csv not found in repository
# emprestimos-20107.csv not found in repository
# emprestimos-20108.csv not found in repository
# emprestimos-20109.csv not found in repository
# emprestimos-20110.csv not found in repository
# emprestimos-20111.csv already downloaded.
# emprestimos-20112.csv already downloaded.
# emprestimos-20113.csv not found in repository
# emprestimos-20114.csv not found in repository
# emprestimos-20115.csv not found in repository
# emprestimos-20116.csv not found in repository
# emprestimos-20117.csv not found in repository
# emprestimos-20118.csv not found in repository
# emprestimos-20119.csv not found in repository
# emprestimos-20120.csv not found in repository
# emprestimos-20121.csv already downloaded.
# emprestimos-20122.csv already downloaded.
# emprestimos-20123.csv not found in repository
# emprestimos-20124.csv not found in repository
# emprestimos-20125.csv not found in repository
# emprestimos-20126.csv not found in repository
# emprestimos-20127.csv not found in repository
# emprestimos-20128.csv not found in repository
# emprestimos-20129.csv not found in repository
# emprestimos-20130.csv not found in repository
# emprestimos-20131.csv already downloaded.
# emprestimos-20132.csv already downloaded.
# emprestimos-20133.csv not found in repository
# emprestimos-20134.csv not found in repository
# emprestimos-20135.csv not found in repository
# emprestimos-20136.csv not found in repository
# emprestimos-20137.csv not found in repository
# emprestimos-20138.csv not found in repository
# emprestimos-20139.csv not found in repository
# emprestimos-20140.csv not found in repository
# emprestimos-20141.csv already downloaded.
# emprestimos-20142.csv already downloaded.
# emprestimos-20143.csv not found in repository
# emprestimos-20144.csv not found in repository
# emprestimos-20145.csv not found in repository
# emprestimos-20146.csv not found in repository
# emprestimos-20147.csv not found in repository
# emprestimos-20148.csv not found in repository
# emprestimos-20149.csv not found in repository
# emprestimos-20150.csv not found in repository
# emprestimos-20151.csv already downloaded.
# emprestimos-20152.csv already downloaded.
# emprestimos-20153.csv not found in repository
# emprestimos-20154.csv not found in repository
# emprestimos-20155.csv not found in repository
# emprestimos-20156.csv not found in repository
# emprestimos-20157.csv not found in repository
# emprestimos-20158.csv not found in repository
# emprestimos-20159.csv not found in repository
# emprestimos-20160.csv not found in repository
# emprestimos-20161.csv already downloaded.
# emprestimos-20162.csv successfully downloaded!
# emprestimos-20163.csv not found in repository
# emprestimos-20164.csv not found in repository
# emprestimos-20165.csv not found in repository
# emprestimos-20166.csv not found in repository
# emprestimos-20167.csv not found in repository
# emprestimos-20168.csv not found in repository
# emprestimos-20169.csv not found in repository
# emprestimos-20170.csv not found in repository
# emprestimos-20171.csv successfully downloaded!
# emprestimos-20172.csv successfully downloaded!
# emprestimos-20173.csv not found in repository
# emprestimos-20174.csv not found in repository
# emprestimos-20175.csv not found in repository
# emprestimos-20176.csv not found in repository
# emprestimos-20177.csv not found in repository
# emprestimos-20178.csv not found in repository
# emprestimos-20179.csv not found in repository
# emprestimos-20180.csv not found in repository
# emprestimos-20181.csv successfully downloaded!
# emprestimos-20182.csv already downloaded.
# emprestimos-20183.csv not found in repository
# emprestimos-20184.csv not found in repository
# emprestimos-20185.csv not found in repository
# emprestimos-20186.csv not found in repository
# emprestimos-20187.csv not found in repository
# emprestimos-20188.csv not found in repository
# emprestimos-20189.csv not found in repository
# emprestimos-20190.csv not found in repository
# emprestimos-20191.csv already downloaded.
# emprestimos-20192.csv already downloaded.
# emprestimos-20193.csv not found in repository
# emprestimos-20194.csv not found in repository
# emprestimos-20195.csv not found in repository
# emprestimos-20196.csv not found in repository
# emprestimos-20197.csv not found in repository
# emprestimos-20198.csv not found in repository
# emprestimos-20199.csv not found in repository
# emprestimos-20200.csv not found in repository
# emprestimos-20201.csv already downloaded.

# %% [markdown]
# ### Reading CSV Files and Concatenating to a Single DataFrame

# %%
#Creating a looping to read all csv files from the directory and concatenate in just one DataFrame
dfs = []
for i in range(2010, 2021):
    df1 = pd.read_csv(f'Dados/Emprestimos/emprestimos-{i}1.csv')
    dfs.append(df1)
    try:
        df2 = pd.read_csv(f'Dados/Emprestimos/emprestimos-{i}2.csv')
        dfs.append(df2)
    except FileNotFoundError:
        pass
emprestimos = pd.concat(dfs, ignore_index=True)
emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1        2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2        2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3        2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...                                ...                            ...
# 2258013  2020/05/05 19:51:06.059000000  2021/05/13 14:53:31.000000000
# 2258014  2020/05/05 19:51:06.135000000  2021/05/13 14:53:38.000000000
# 2258015  2020/05/05 19:51:06.164000000  2021/05/13 15:01:46.000000000
# 2258016  2020/06/09 11:54:02.669000000  2021/07/21 15:33:55.000000000
# 2258017  2020/06/09 11:54:02.852000000  2021/07/21 15:33:45.000000000
#
#          matricula_ou_siape             tipo_vinculo_usuario
# 0              2.008023e+09               ALUNO DE GRADUAÇÃO
# 1              2.008023e+09               ALUNO DE GRADUAÇÃO
# 2              2.008112e+09           ALUNO DE PÓS-GRADUAÇÃO
# 3              2.007211e+08               ALUNO DE GRADUAÇÃO
# 4              2.008023e+09               ALUNO DE GRADUAÇÃO
# ...                     ...                              ...
# 2258013        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258014        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258015        3.067431e+06  SERVIDOR TÉCNICO-ADMINISTRATIVO
# 2258016        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
# 2258017        2.020101e+10           ALUNO DE PÓS-GRADUAÇÃO
#
# [2258018 rows x 7 columns]

# %% [markdown]
# ### Check and Remove Null Values and Duplicates in DataFrame

# %%
#check null values
print(f'Total null values ​​in DataFrame:\n{emprestimos.isnull().sum()}')
# Out:
# Total null values ​​in DataFrame:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1285720
# data_emprestimo               0
# data_devolucao             6471
# matricula_ou_siape         3170
# tipo_vinculo_usuario          0
# dtype: int64

# %%
#check duplicates
print(f'Total duplicates in DataFrame: {emprestimos.duplicated().sum()}')
# Out:
# Total duplicates in DataFrame: 37

# %%
#Removing Null Values and Duplicates in DataFrame
emprestimos.drop_duplicates(inplace=True)
emprestimos.dropna(inplace=True)

# %%
#Checking if there are still duplicates or null values ​​in the DataFrame
duplicates = emprestimos.duplicated().sum()
null_values = emprestimos.isnull().sum().sum()
print(f'Total duplicates: {duplicates}')
print(f'Total null values: {null_values}')
# Out:
# Total duplicates: 0
# Total null values: 0

# %% [markdown]
# ### Importing copies of the collection

# %%
#Importing copy
exemplares = pd.read_parquet('Dados/Exemplar/dados_exemplares.parquet')
exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# 3                          Biblioteca Central Zila Mamede         REGULAR
# 5                          Biblioteca Central Zila Mamede        ESPECIAL
# ...                                                   ...             ...
# 568580  Biblioteca Setorial do Núcleo de Educação da I...         REGULAR
# 568581                     Biblioteca Central Zila Mamede        ESPECIAL
# 568582                     Biblioteca Central Zila Mamede        ESPECIAL
# 568583                     Biblioteca Central Zila Mamede        ESPECIAL
# 568584                     Biblioteca Central Zila Mamede        ESPECIAL
#
#         localizacao  registro_sistema
# index
# 0               694                 1
# 1               688                 1
# 2               638                 1
# 3               616                 5
# 5               657                15
# ...             ...               ...
# 568580          951            268231
# 568581          997            268233
# 568582          987            268234
# 568583          764            268235
# 568584          962            268236
#
# [546237 rows x 7 columns]

# %% [markdown]
# ### Join Exemplar to the treated Frame of the loan variable

# %%
loans_new = emprestimos.merge(exemplares)
loans_new
# Out:
#         id_emprestimo codigo_barras                 data_renovacao  \
# 0              709686    2006017618  2010/01/26 08:07:01.738000000
# 1              749227    2006017618  2010/04/19 17:35:25.987000000
# 2             1175444    2006017618  2012/03/11 17:05:30.982000000
# 3             1209694    2006017618  2012/04/11 12:34:59.458000000
# 4             1374962    2006017618  2012/12/12 07:40:40.406000000
# ...               ...           ...                            ...
# 906407        2988812    2016019436  2020/04/26 11:43:40.062000000
# 906408        2988874    2010080699  2021/08/10 02:30:14.871000000
# 906409        2988922    2018031109  2020/03/29 10:17:16.672000000
# 906410        2988968    2016033194  2020/04/06 18:21:57.168000000
# 906411        2989007    2014069838  2020/03/23 10:42:38.432000000
#
#                       data_emprestimo                 data_devolucao  \
# 0       2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 1       2010/04/05 11:25:57.627000000  2010/04/27 11:37:02.530000000
# 2       2012/02/24 16:18:40.959000000  2012/03/28 14:32:13.000000000
# 3       2012/03/28 14:33:04.249000000  2012/04/25 11:48:28.000000000
# 4       2012/11/14 12:41:25.081000000  2013/01/15 17:10:17.000000000
# ...                               ...                            ...
# 906407  2020/03/17 16:20:01.992000000  2021/06/09 12:33:39.000000000
# 906408  2020/03/17 17:07:40.834000000  2022/02/17 11:48:53.000000000
# 906409  2020/03/17 17:45:40.794000000  2021/03/25 10:22:11.000000000
# 906410  2020/03/17 18:33:29.752000000  2021/06/15 16:52:35.000000000
# 906411  2020/03/17 19:29:17.897000000  2022/01/20 17:26:19.000000000
#
#         matricula_ou_siape    tipo_vinculo_usuario  id_exemplar  \
# 0             2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO       195347
# 1             2.011105e+09  ALUNO DE PÓS-GRADUAÇÃO       195347
# 2             2.010057e+09      ALUNO DE GRADUAÇÃO       195347
# 3             2.010057e+09      ALUNO DE GRADUAÇÃO       195347
# 4             2.011104e+09  ALUNO DE PÓS-GRADUAÇÃO       195347
# ...                    ...                     ...          ...
# 906407        2.016103e+10  ALUNO DE PÓS-GRADUAÇÃO      1235460
# 906408        2.017015e+10      ALUNO DE GRADUAÇÃO       826353
# 906409        2.018013e+10      ALUNO DE GRADUAÇÃO      1342486
# 906410        2.016014e+10      ALUNO DE GRADUAÇÃO      1310816
# 906411        2.019005e+10      ALUNO DE GRADUAÇÃO      1317032
#
#                   colecao                                         biblioteca  \
# 0       Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - E...
# 1       Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - E...
# 2       Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - E...
# 3       Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - E...
# 4       Acervo Circulante  Biblioteca Setorial Prof. Rodolfo Helinski - E...
# ...                   ...                                                ...
# 906407  Acervo Circulante                     Biblioteca Central Zila Mamede
# 906408  Acervo Circulante                     Biblioteca Central Zila Mamede
# 906409  Acervo Circulante                     Biblioteca Central Zila Mamede
# 906410  Acervo Circulante  Biblioteca Setorial da Faculdade de Ciências d...
# 906411  Acervo Circulante  Biblioteca Setorial da Faculdade de Ciências d...
#
#        status_material  localizacao  registro_sistema
# 0              REGULAR          640             75019
# 1              REGULAR          640             75019
# 2              REGULAR          640             75019
# 3              REGULAR          640             75019
# 4              REGULAR          640             75019
# ...                ...          ...               ...
# 906407         REGULAR          511            233523
# 906408         REGULAR          660            134891
# 906409         REGULAR          717            264237
# 906410         REGULAR          785            253484
# 906411         REGULAR          626            168065
#
# [906412 rows x 13 columns]
